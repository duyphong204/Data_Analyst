# %% [markdown]
# # Sử dụng dtale trên dữ liệu Marketing Campaign.

# %% [markdown]
# ## Cài thư viện dtale

# %%
# !pip install dtale
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/642.7 kB ? eta -:--:--
#      ---------------------------------------- 642.7/642.7 kB 4.8 MB/s  0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached xlrd-2.0.2-py2.py3-none-any.whl.metadata (3.5 kB)
# ...
#    ---------------------------------------- 0.0/17.6 MB ? eta -:--:--
#    ----- ---------------------------------- 2.6/17.6 MB 12.6 MB/s eta 0:00:02
#    -------------- ------------------------- 6.3/17.6 MB 14.9 MB/s eta 0:00:01
#    -------------------- ------------------- 9.2/17.6 MB 15.9 MB/s eta 0:00:01
#    -------------------------------- ------- 14.2/17.6 MB 17.1 MB/s eta 0:00:01
#    ---------------------------------------  17.6/17.6 MB 17.3 MB/s eta 0:00:01
#    ---------------------------------------- 17.6/17.6 MB 16.8 MB/s  0:00:01
# ...

# %% [markdown]
# ## Import thư viện

# %%
import pandas as pd
import dtale

# %% [markdown]
# ## Khám phá dữ liệu Marketing với D-Tale

# %%
# Đọc dữ liệu marketing từ file CSV (tab-separated) vào DataFrame
marketing_data = pd.read_csv("marketing_campaign.csv", sep='\t')

# Mở giao diện tương tác D-Tale trên trình duyệt để khám phá dữ liệu
dtale.show(marketing_data).open_browser()
